# %%
#0918:all question and column links from topic "基因编辑" 
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver
from bs4 import BeautifulSoup
from lxml import etree
from pyquery import PyQuery as pq
import pandas as pd
from pandas import Series, DataFrame
import csv
import urllib.request
import datetime
import time
import re

#------------------------------------------------------------1st stage,collect all question/column links
driver = webdriver.Chrome()
url = "https://www.zhihu.com/topic/20741067/hot"
    
driver.get(url)
driver.implicitly_wait(10)

time.sleep(2)

#scroll to the topic bottom
for i in range(110):
    js = "var q = document.documentElement.scrollTop="+str(i*1000)
    driver.execute_script(js)
    time.sleep(1.8)
time.sleep(2)

listql = []
soup = BeautifulSoup(driver.page_source,"lxml")
for b in soup.findAll("meta",attrs = {"itemprop":"url"}):
    c = b["content"]
    if "question" in c and "answer" not in c and c not in listql:
        listql.append(c) 
    if "zhuanlan" in c and c not in listql:
        listql.append(c) 

#url = "https://www.zhihu.com/topic/20741067/top-answers"
driver.find_element_by_link_text("精华").click()
time.sleep(2)
driver.implicitly_wait(10)
time.sleep(2)

#scroll to the topic bottom
for i in range(30):
    js = "var q = document.documentElement.scrollTop="+str(i*1000)
    driver.execute_script(js)
    time.sleep(1.5)
time.sleep(2)

soup = BeautifulSoup(driver.page_source,"lxml")
for b in soup.findAll("meta",attrs = {"itemprop":"url"}):
    c = b["content"]
    if "question" in c and "answer" not in c and c not in listql:
        listql.append(c) 
    if "zhuanlan" in c and c not in listql:
        listql.append(c) 

        
#url = "https://www.zhihu.com/topic/20741067/unanswered"
driver.find_element_by_link_text("等待回答").click()
driver.implicitly_wait(10)
time.sleep(2)

#scroll to the topic bottom
for i in range(20):
    js = "var q = document.documentElement.scrollTop="+str(i*1000)
    driver.execute_script(js)
    time.sleep(1.5)
time.sleep(2)

soup = BeautifulSoup(driver.page_source,"lxml")
for b in soup.findAll("a"):
    c = b["href"]
    d = "https://www.zhihu.com" + c
    if "question" in c and len(c) == 19 and "topic" not in c and "write_answer" not in c and d not in listql:
        listql.append(d)

listql = [re.sub("^https:/+","https://",i) for i in listql]

save = "/Users/CM/desktop/ScrapeZQ2/QClink/ql-jybj.csv"
df = pd.DataFrame(listql,columns = ["QClink"])
df1 = df.to_csv(save, index = False)
print(pd.read_csv(save))
#------------------------------------------------------------2nd stage,collect question/column details
driver.quit()
# Out:
#                                        QClink
# 0    https://www.zhihu.com/question/310424496
# 1    https://www.zhihu.com/question/345628210
# 2       https://zhuanlan.zhihu.com/p/82468766
# 3       https://zhuanlan.zhihu.com/p/82217116
# 4       https://zhuanlan.zhihu.com/p/81803344
# 5       https://zhuanlan.zhihu.com/p/80627348
# 6       https://zhuanlan.zhihu.com/p/80629491
# 7       https://zhuanlan.zhihu.com/p/80044731
# 8       https://zhuanlan.zhihu.com/p/78802286
# 9       https://zhuanlan.zhihu.com/p/77983758
# 10      https://zhuanlan.zhihu.com/p/76296904
# 11      https://zhuanlan.zhihu.com/p/75944481
# 12   https://www.zhihu.com/question/345987710
# 13      https://zhuanlan.zhihu.com/p/75286182
# 14      https://zhuanlan.zhihu.com/p/74254572
# 15      https://zhuanlan.zhihu.com/p/73875825
# 16   https://www.zhihu.com/question/335058097
# 17      https://zhuanlan.zhihu.com/p/73861802
# 18      https://zhuanlan.zhihu.com/p/72364998
# 19   https://www.zhihu.com/question/345898273
# 20      https://zhuanlan.zhihu.com/p/73374896
# 21      https://zhuanlan.zhihu.com/p/73326757
# 22      https://zhuanlan.zhihu.com/p/82258751
# 23      https://zhuanlan.zhihu.com/p/80084113
# 24      https://zhuanlan.zhihu.com/p/71787061
# 25   https://www.zhihu.com/question/346311185
# 26      https://zhuanlan.zhihu.com/p/79963901
# 27      https://zhuanlan.zhihu.com/p/79960607
# 28   https://www.zhihu.com/question/329600199
# 29      https://zhuanlan.zhihu.com/p/69810623
# ..                                        ...
# 360  https://www.zhihu.com/question/345884726
# 361  https://www.zhihu.com/question/345884816
# 362  https://www.zhihu.com/question/330118534
# 363  https://www.zhihu.com/question/323581581
# 364  https://www.zhihu.com/question/346250759
# 365  https://www.zhihu.com/question/320851622
# 366  https://www.zhihu.com/question/317091956
# 367  https://www.zhihu.com/question/335644224
# 368  https://www.zhihu.com/question/335886708
# 369  https://www.zhihu.com/question/322125352
# 370  https://www.zhihu.com/question/309866322
# 371  https://www.zhihu.com/question/342476492
# 372  https://www.zhihu.com/question/336761861
# 373  https://www.zhihu.com/question/321220018
# 374  https://www.zhihu.com/question/346040219
# 375  https://www.zhihu.com/question/342676451
# 376  https://www.zhihu.com/question/319815521
# 377  https://www.zhihu.com/question/346166167
# 378  https://www.zhihu.com/question/345986898
# 379  https://www.zhihu.com/question/334727681
# 380  https://www.zhihu.com/question/332603833
# 381  https://www.zhihu.com/question/327318759
# 382  https://www.zhihu.com/question/327204692
# 383  https://www.zhihu.com/question/322175810
# 384  https://www.zhihu.com/question/321378171
# 385  https://www.zhihu.com/question/320531089
# 386  https://www.zhihu.com/question/317493895
# 387  https://www.zhihu.com/question/317103624
# 388  https://www.zhihu.com/question/316923397
# 389  https://www.zhihu.com/question/309844410
#
# [390 rows x 1 columns]

# %%
#0918:question and column detail from topic "crispr" 
driver = webdriver.Chrome()

#scan the QR code manually to login
driver.get("https://www.zhihu.com/")
time.sleep(12)

with open("/Users/CM/desktop/ScrapeZQ2/qca-jybj.csv","w",encoding = "utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["column","title","flwr","v","authlink","upno","cmtno","andate","textlen","imgno","antext"])
    df1 = pd.read_csv("/Users/CM/desktop/ScrapeZQ2/QClink/ql-jybj.csv")["QClink"].values

    for qcl in df1:
        driver.get(qcl)
        time.sleep(1)
        soup = BeautifulSoup(driver.page_source,"lxml")
    
        try:            
            if "question" in qcl:
                #unfold qtext
                time.sleep(1)
                try:
                    driver.find_element_by_xpath("//div[@class='QuestionRichText QuestionRichText--expandable QuestionRichText--collapsed']").click()
                    time.sleep(1)
                except:
                    time.sleep(1)
                
                #get question info
                column = "0"
                qtitle = soup.find("h1", class_="QuestionHeader-title").get_text()+soup.find("div", class_="QuestionHeader-detail").get_text()
                qflwr = soup.findAll("strong", class_="NumberBoard-itemValue")[0].get_text()
                qv = soup.findAll("strong", class_="NumberBoard-itemValue")[1].get_text()                

                if len(soup.findAll("h4", class_="List-headerText")) > 0:                   
                    #scroll to the bottom
                    xhd = soup.findAll("button", class_="Button QuestionAnswers-answerButton Button--blue Button--spread")
                    an = soup.findAll("span", class_="RichText ztext CopyrightRichText-richText")
                    if len(an) > 0:
                        n = 1
                        while len(xhd) == 0:
                            js = "var q = document.documentElement.scrollTop="+str(n*1000)
                            driver.execute_script(js)
                            soup = BeautifulSoup(driver.page_source,"lxml")
                            xhd = soup.findAll("button", class_="Button QuestionAnswers-answerButton Button--blue Button--spread")
                            n+=1
                            time.sleep(0.6)
                    
                    #get all answer info
                    ans = soup.findAll("div", class_="List-item")
                    for ai in ans:
                        try:
                            authlink = re.sub("^//","https://",ai.find("a", class_="UserLink-link")["href"])
                        except:
                            authlink = "AnonymousUser"
                        upno = ai.find("button", class_="Button VoteButton VoteButton--up").get_text()
                        cmtno = ai.find("button", class_="Button ContentItem-action Button--plain Button--withIcon Button--withLabel").get_text()
                        andate = ai.find("div", class_="ContentItem-time").get_text()
                        imgno = str(len(ai.findAll("figure")))+"个图片"
                        antext = ai.find("span", class_="RichText ztext CopyrightRichText-richText").get_text()
                        textlen = str(len(antext))+"个文字"
                        writer.writerow([column,qtitle,qflwr,qv,authlink,upno,cmtno,andate,textlen,imgno,antext])
                else:
                    authlink = "AnonymousUser"
                    writer.writerow([column,qtitle,qflwr,qv,authlink])                   
                    
            elif "zhuanlan" in qcl:
                 
                column = "1"
                coltitle = soup.find("h1", class_="Post-Title").get_text()
                colflwr = "NoColflwr"
                colv = "NoColv"
                authlink = re.sub("^//","https://",soup.find("a", class_="UserLink-link")["href"])
                upno = soup.find("button", class_="Button VoteButton VoteButton--up").get_text()
                cmtno = soup.find("button", class_="Button BottomActions-CommentBtn Button--plain Button--withIcon Button--withLabel").get_text()
                coldate = soup.find("div", class_="ContentItem-time").get_text()
                imgno = str(len(soup.findAll("figure")))+"个图片"
                coltext = soup.find("div", class_="Post-RichTextContainer").get_text()
                textlen = str(len(coltext))+"个文字"
                writer.writerow([column,coltitle,colflwr,colv,authlink,upno,cmtno,coldate,textlen,imgno,coltext])
            time.sleep(2)
            
        except:
            print(qcl) 
            #fill up manually

print("done.")
time.sleep(1)
driver.quit()
# Out:
# https://www.zhihu.com/question/345898273
# https://www.zhihu.com/question/346311185
# https://www.zhihu.com/question/342351362
# https://www.zhihu.com/question/313198233
# https://www.zhihu.com/question/332658257
# https://www.zhihu.com/question/333275895
# https://www.zhihu.com/question/324140369
# https://www.zhihu.com/question/335907274
# https://www.zhihu.com/question/310187816
# https://www.zhihu.com/question/337788974
# https://www.zhihu.com/question/333322250
# https://www.zhihu.com/question/330015812
# https://www.zhihu.com/question/334494282
# https://www.zhihu.com/question/333150456
# https://www.zhihu.com/question/321581698
# https://www.zhihu.com/question/311124544
# https://www.zhihu.com/question/320299987
# https://www.zhihu.com/question/341402827
# https://www.zhihu.com/question/343261964
# https://www.zhihu.com/question/323507951
# https://www.zhihu.com/question/334401115
# https://www.zhihu.com/question/337823186
# https://www.zhihu.com/question/312118941
# https://www.zhihu.com/question/322552456
# https://www.zhihu.com/question/311889646
# https://www.zhihu.com/question/336790907
# https://www.zhihu.com/question/330118534
# https://www.zhihu.com/question/323581581
# https://www.zhihu.com/question/346250759
# https://www.zhihu.com/question/335644224
# https://www.zhihu.com/question/335886708
# done.

# %%
#0918 question error page processing
qlerr = ["https://www.zhihu.com/question/335886708"]

driver = webdriver.Chrome()
#scan the QR code manually to login
#driver.get("https://www.zhihu.com/")
#time.sleep(8)

with open("/Users/CM/desktop/ScrapeZQ2/qca-jybj1.csv","w",encoding = "utf-8") as f:
        writer = csv.writer(f)
        for ql in qlerr:
            
            driver.get(ql)
            #time.sleep(8)
            soup = BeautifulSoup(driver.page_source,"lxml")
            
            try:
                
            
                #unfold qtext
                time.sleep(1)
                try:
                    driver.find_element_by_xpath("//div[@class='QuestionRichText QuestionRichText--expandable QuestionRichText--collapsed']").click()
                    time.sleep(1)
                except:
                    time.sleep(1)
                
                #get question info
                column = "0"
                qtitle = soup.find("h1", class_="QuestionHeader-title").get_text()+soup.find("div", class_="QuestionHeader-detail").get_text()
                qflwr = soup.findAll("strong", class_="NumberBoard-itemValue")[0].get_text()
                qv = soup.findAll("strong", class_="NumberBoard-itemValue")[1].get_text()                
    
                if len(soup.findAll("h4", class_="List-headerText")) > 0:                   
                    #scroll to the bottom
                    xhd = soup.findAll("button", class_="Button QuestionAnswers-answerButton Button--blue Button--spread")
                    an = soup.findAll("span", class_="RichText ztext CopyrightRichText-richText")
                    if len(an) > 0:
                        n = 1
                        while len(xhd) == 0:
                            js = "var q = document.documentElement.scrollTop="+str(n*1000)
                            driver.execute_script(js)
                            soup = BeautifulSoup(driver.page_source,"lxml")
                            xhd = soup.findAll("button", class_="Button QuestionAnswers-answerButton Button--blue Button--spread")
                            n+=1
                            time.sleep(0.6)
                    
                    #get all answer info
                    soup = BeautifulSoup(driver.page_source,"lxml")
                    ans = soup.findAll("div", class_="List-item")
                    for ai in ans:
                        try:
                            authlink = re.sub("^//","https://",ai.find("a", class_="UserLink-link")["href"])
                        except:
                            authlink = "AnonymousUser"
                        upno = ai.find("button", class_="Button VoteButton VoteButton--up").get_text()
                        cmtno = ai.find("button", class_="Button ContentItem-action Button--plain Button--withIcon Button--withLabel").get_text()
                        andate = ai.find("div", class_="ContentItem-time").get_text()
                        imgno = str(len(ai.findAll("figure")))+"个图片"
                        antext = ai.find("span", class_="RichText ztext CopyrightRichText-richText").get_text()
                        textlen = str(len(antext))+"个文字"
                        writer.writerow([column,qtitle,qflwr,qv,authlink,upno,cmtno,andate,textlen,imgno,antext])
                else:
                    authlink = "AnonymousUser"
                    writer.writerow([column,qtitle,qflwr,qv,authlink])  
            except:
                print(ql)


    
print("done.")
driver.quit()
# Out:
# done.

# %%
#0918:answerers detail in topic "基因编辑" ,cant deal with users are banned or has 0 upvote.
driver = webdriver.Chrome()

#scan the QR code manually to login
driver.get("https://www.zhihu.com/")
time.sleep(10)

with open("/Users/CM/desktop/ScrapeZQ2/ai-jybj1.csv","w",encoding = "utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["authlink","authname","verified","authflwr","authupno"])
    #df2 = pd.read_csv("/Users/CM/desktop/ScrapeZQ2/qca-jybj.csv")["authlink"].values
    df2 = [] 
    for al in df2:
        if al != "AnonymousUser":
            driver.get(al)
            driver.implicitly_wait(8)
            soup = BeautifulSoup(driver.page_source,"lxml")
            
            try:
                if len(soup.findAll("div", class_="ProfileMainPrivacy-mainContentWrapper")) == 0:
                    authlink = al
                    authname = soup.find("span",class_="ProfileHeader-name").get_text()
                    if soup.find("div", class_="Card-headerText").get_text() == "个人成就":
                        verified = "0"
                    if soup.find("div", class_="Card-headerText").get_text() == "认证与成就":
                        verified = "1"
                    authflwr = soup.findAll("strong", class_="NumberBoard-itemValue")[1].get_text()
                    for i in soup.findAll("div", class_="IconGraf"):
                        if "赞同" in i.get_text():
                            authupno = i.get_text()
                    writer.writerow([authlink,authname,verified,authflwr,authupno])
                    time.sleep(1)
            except:
                print(al)
print("done.")
            
time.sleep(1)
driver.quit()
# Out:
# https://www.zhihu.com/people/hei-bai-ye-34
# https://www.zhihu.com/people/chu-qi-37-98
# https://www.zhihu.com/people/heng-ye-44
# https://www.zhihu.com/people/hei-bai-ye-34
# https://www.zhihu.com/people/liu-kang-88-42
# https://www.zhihu.com/people/c-ying-37
# https://www.zhihu.com/people/xin-li-de-sha-ma-te
# https://www.zhihu.com/people/xiao-yao-you-66-41
# https://www.zhihu.com/people/hu-nan-sheng-sheng-chang
# https://www.zhihu.com/people/luan-shi-de-mi-51
# https://www.zhihu.com/people/zhui-meng-31-83
# https://www.zhihu.com/people/sjfgs
# https://www.zhihu.com/people/wang-yu-jue-56-82
# https://www.zhihu.com/org/ying-mao-sheng-ye-sheng-wu-ke-ji-74
# https://www.zhihu.com/org/ying-mao-sheng-ye-sheng-wu-ke-ji-74
# https://www.zhihu.com/people/inovogen
# https://www.zhihu.com/people/bei-jing-jia-mei-shi-yan
# https://www.zhihu.com/people/kyrie-wang
# https://www.zhihu.com/org/wang-sheng-sheng-wu-oneshine
# done.

# %%
#0915:answerers detail in topic "基因编辑" 
driver = webdriver.Chrome()

#scan the QR code manually to login
driver.get("https://www.zhihu.com/")
time.sleep(10)

with open("/Users/CM/desktop/ScrapeZQ2/ai-jybj1.csv","w",encoding = "utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["authlink","authname","verified","authflwr","authupno"])
    df2 = pd.read_csv("/Users/CM/desktop/ScrapeZQ2/alerr-jybj.csv")["authlink"].values
    for al in df2:
        if al != "AnonymousUser":
            driver.get(al)
            driver.implicitly_wait(8)
            soup = BeautifulSoup(driver.page_source,"lxml")
            
            try:
                if len(soup.findAll("div", class_="ProfileMainPrivacy-mainContentWrapper")) == 0:
                    authlink = al
                    authname = soup.find("span",class_="ProfileHeader-name").get_text()
                    if soup.find("div", class_="Card-headerText").get_text() == "个人成就":
                        verified = "0"
                    if soup.find("div", class_="Card-headerText").get_text() == "认证与成就":
                        verified = "1"
                    authflwr = soup.findAll("strong", class_="NumberBoard-itemValue")[1].get_text()
                    try:
                        for i in soup.findAll("div", class_="IconGraf"):
                            if "赞同" in i.get_text():
                                authupno = i.get_text()
                    except:
                        authupno = "获得 0 次赞同"
                    writer.writerow([authlink,authname,verified,authflwr,authupno])
                    time.sleep(1)
            except:
                print(al)
print("done.")
            
time.sleep(1)
driver.quit()
# Out:
# https://www.zhihu.com/people/hei-bai-ye-34
# https://www.zhihu.com/people/chu-qi-37-98
# https://www.zhihu.com/people/heng-ye-44
# https://www.zhihu.com/people/hei-bai-ye-34
# https://www.zhihu.com/people/liu-kang-88-42
# https://www.zhihu.com/people/c-ying-37
# https://www.zhihu.com/people/xin-li-de-sha-ma-te
# https://www.zhihu.com/people/xiao-yao-you-66-41
# https://www.zhihu.com/people/hu-nan-sheng-sheng-chang
# https://www.zhihu.com/people/luan-shi-de-mi-51
# https://www.zhihu.com/people/zhui-meng-31-83
# done.

# %%
len("我认为贺健奎的实验目的不是增强人类的智力 (designer baby)因为从目前的研究结果来看, 有很多基因的单核苷酸多态性 (你可以认为是突变) 对智力的影响比CCR5大.(我随手翻了篇文章, 没看内容)而且很早之前就有'聪明鼠'的实验, 把一整个基因转到老鼠里, 老鼠变聪明了.所以一个聪明人如果想偷偷的做设计婴儿的实验, 有很多表型更明显的基因可以选择. 用人话表达就是他可以编辑其他基因, 能得到更强的婴儿.  CCR5即使对智力有影响, 恐怕效果也没有那么强.如果他的目的是弄出更聪明的婴儿, 那检测实验成功的难度就比较大了. 被编辑的儿童的智商总得超过人群平均值两个标准差, 也就是130以上, 才能宣称实验成功把..  这个风险太大了, 而且实验需要花费的时间也太长. 他恐怕收不回成本.CRISPR编辑基因会有很多意想不到的问题, 直接在人胚胎做毫无意义的编辑就更是瞎扯淡了.....")
# Out:
# 401
